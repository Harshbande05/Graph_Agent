# %%
from langchain_core.messages import HumanMessage, AIMessage

history = [
    # HumanMessage(content="Hi, I am Harsh. An AI Engineer."),
    AIMessage(content="Hi Harsh! It's great to meet you."),
]

# %%
for x in history:
    if isinstance(x, HumanMessage):
        print(True)
    else:
        print(False)
# Out:
# False
